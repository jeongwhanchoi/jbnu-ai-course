# %% [markdown]
# # SVM Using scikit-learn

# %%
from sklearn.svm import SVC
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import numpy as np
from plotdregion import plot_decision_region
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
X = np.random.randn(200, 2)
y = np.logical_xor(X[:,0]>0, X[:,1]>0)
y = np.where(y, 1, -1)

# %%
plt.scatter(X[y==1, 0], X[y==1, 1], color = 'b', marker = 'x', label='1')
plt.scatter(X[y==-1, 0], X[y==-1, 1], color = 'r', marker = 'o', label='-1')
plt.ylim(-3.0)
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
model = SVC(kernel='rbf', C=10.0, gamma=0.10, random_state=None)
model.fit(X_train_std, y_train)
y_pred = model.predict(X_test_std)

print('Total number of tests: %d, Total number of errors: %d' % (len(y_test), (y_test != y_pred).sum()))
print('Accuracy: %.2f' %accuracy_score(y_test, y_pred))
# Out:
# Total number of tests: 60, Total number of errors: 6
# Accuracy: 0.90

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
plot_decision_region(X=X_combined_std, y=y_combined, classifier=model, test_idx=range(105,150),title='scikit-learn SVM')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
model_high_gamma = SVC(kernel='rbf', C=10.0, gamma=1.0, random_state=None)
model_high_gamma.fit(X_train_std, y_train)
y_pred = model_high_gamma.predict(X_test_std)

print('Total number of tests: %d, Total number of errors: %d' % (len(y_test), (y_test != y_pred).sum()))
print('Accuracy: %.2f' %accuracy_score(y_test, y_pred))
# Out:
# Total number of tests: 60, Total number of errors: 2
# Accuracy: 0.97

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
plot_decision_region(X=X_combined_std, y=y_combined, classifier=model_high_gamma, test_idx=range(105,150),title='scikit-learn SVM')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
